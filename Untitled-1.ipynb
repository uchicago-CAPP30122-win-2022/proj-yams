# %%
import util
import pandas as pd
import build_dataframes
import geo_comm_areas as gca
import geopandas as gpd
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# /home/anth0nyhak1m/.local/lib/python3.8/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# /tmp/ipykernel_18449/486794029.py:3: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   import build_dataframes
# /home/anth0nyhak1m/comp_sci/capp30122/proj-yams/build_dataframes.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   census['year'] = '2010'

# %%
build_dataframes.merge_dfs()
# Out:
#      area_num  year           community  \
# 0           1  2006         ROGERS PARK
# 1           2  2006          WEST RIDGE
# 2           3  2006              UPTOWN
# 3           4  2006      LINCOLN SQUARE
# 4           5  2006        NORTH CENTER
# ...       ...   ...                 ...
# 1227       73  2021  WASHINGTON HEIGHTS
# 1228       74  2021     MOUNT GREENWOOD
# 1229       75  2021         MORGAN PARK
# 1230       76  2021               OHARE
# 1231       77  2021           EDGEWATER
#
#                                                geometry  tot_pop  \
# 0     MULTIPOLYGON (((-87.65456 41.99817, -87.65574 ...    55628
# 1     MULTIPOLYGON (((-87.68465 42.01948, -87.68464 ...    77122
# 2     MULTIPOLYGON (((-87.64102 41.95480, -87.64400 ...    57182
# 3     MULTIPOLYGON (((-87.67441 41.97610, -87.67440 ...    40494
# 4     MULTIPOLYGON (((-87.67336 41.93234, -87.67342 ...    35114
# ...                                                 ...      ...
# 1227  MULTIPOLYGON (((-87.63373 41.72885, -87.63369 ...    25065
# 1228  MULTIPOLYGON (((-87.69646 41.70714, -87.69644 ...    18628
# 1229  MULTIPOLYGON (((-87.64215 41.68508, -87.64249 ...    21186
# 1230  MULTIPOLYGON (((-87.83658 41.98640, -87.83658 ...    13418
# 1231  MULTIPOLYGON (((-87.65456 41.99817, -87.65456 ...    56296
#
#       Number built per 10,000 people  Number demolished per 10,000 people  \
# 0                           3.056015                             1.797656
# 1                           4.538264                             3.371282
# 2                           4.197125                             3.497604
# 3                          11.606658                             9.137156
# 4                          48.128951                            36.452697
# ...                              ...                                  ...
# 1227                        0.797925                             2.393776
# 1228                        4.294610                             3.220958
# 1229                        0.944020                             3.304069
# 1230                        0.000000                             2.235803
# 1231                        2.664488                             0.532898
#
#       build ratio  vac_rate  hisp_per  white_per  black_per  asian_per  \
# 0        1.700000       NaN       NaN        NaN        NaN        NaN
# 1        1.346154       NaN       NaN        NaN        NaN        NaN
# 2        1.200000       NaN       NaN        NaN        NaN        NaN
# 3        1.270270       NaN       NaN        NaN        NaN        NaN
# 4        1.320312       NaN       NaN        NaN        NaN        NaN
# ...           ...       ...       ...        ...        ...        ...
# 1227     0.333333       NaN       NaN        NaN        NaN        NaN
# 1228     1.333333       NaN       NaN        NaN        NaN        NaN
# 1229     0.285714       NaN       NaN        NaN        NaN        NaN
# 1230     0.000000       NaN       NaN        NaN        NaN        NaN
# 1231     5.000000       NaN       NaN        NaN        NaN        NaN
#
#       Average Homicide  Number of Homicides  grocery stores count  \
# 0             4.772727                  3.0                   NaN
# 1             2.681818                  2.0                   NaN
# 2             4.363636                  3.0                   NaN
# 3             0.863636                  0.0                   NaN
# 4             1.000000                  1.0                   NaN
# ...                ...                  ...                   ...
# 1227          8.181818                 13.0                   NaN
# 1228          0.136364                  0.0                   NaN
# 1229          4.045455                  4.0                   NaN
# 1230          0.227273                  0.0                   NaN
# 1231          2.363636                  1.0                   NaN
#
#       liquor stores count  liquor stores percent percent_of_housing_crowded  \
# 0                     NaN                    NaN                        NaN
# 1                     NaN                    NaN                        NaN
# 2                     NaN                    NaN                        NaN
# 3                     NaN                    NaN                        NaN
# 4                     NaN                    NaN                        NaN
# ...                   ...                    ...                        ...
# 1227                  NaN                    NaN                        NaN
# 1228                  NaN                    NaN                        NaN
# 1229                  NaN                    NaN                        NaN
# 1230                  NaN                    NaN                        NaN
# 1231                  NaN                    NaN                        NaN
#
#      hardship_index
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1227            NaN
# 1228            NaN
# 1229            NaN
# 1230            NaN
# 1231            NaN
#
# [1232 rows x 20 columns]

# %% [markdown]
# vac_rate, build_per_demo (this is our index), hispper, whiteper, blackper
