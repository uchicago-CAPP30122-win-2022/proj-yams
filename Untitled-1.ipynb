# %%
import api_collection
import pandas as pd
import build_dataframes
import geo_comm_areas as gca

crime = api_collection.process_crime("ijzp-q8t2")

# %%
grocery = api_collection.process_grocery_stores("4u6w-irs9")

# %%
socio = api_collection.process_socio_indicators("kn9c-c2s2")

# %%
gca.get_geo_comm_areas()
# Out:
#                  community  area_num  \
# 0                  DOUGLAS        35
# 1                  OAKLAND        36
# 2              FULLER PARK        37
# 3          GRAND BOULEVARD        38
# 4                  KENWOOD        39
# 5           LINCOLN SQUARE         4
# 6          WASHINGTON PARK        40
# 7                HYDE PARK        41
# 8                 WOODLAWN        42
# 9              ROGERS PARK         1
# 10          JEFFERSON PARK        11
# 11             FOREST GLEN        12
# 12              NORTH PARK        13
# 13             ALBANY PARK        14
# 14            PORTAGE PARK        15
# 15             IRVING PARK        16
# 16                 DUNNING        17
# 17               MONTCLARE        18
# 18          BELMONT CRAGIN        19
# 19              WEST RIDGE         2
# 20                 HERMOSA        20
# 21                AVONDALE        21
# 22            LOGAN SQUARE        22
# 23           HUMBOLDT PARK        23
# ...

# %%
comm_areas, build_year_val = build_dataframes.return_marcs_dfs()

# %%
comm_areas.columns
# Out:
# Index(['community', 'area_num', 'geometry', 'demos', 'builds',
#        'tot_build_value', 'comm_name', 'tot_pop', 'pop_hh', 'pop_gq', 'hisp',
#        'white', 'black', 'asian', 'other', 'total_homes', 'tot_hh',
#        'vac_homes', 'hh_size', 'vac_rate', 'hisp_per', 'white_per',
#        'black_per', 'asian_per', 'demo_rate', 'build_rate',
#        'build_val_per_cap', 'ave_build_val', 'build_per_demo'],
#       dtype='object')

# %% [markdown]
# vac_rate, build_per_demo (this is our index), hispper, whiteper, blackper

# %%
build_year_val.melt(id_vars = ['area_num', 'community', 'geometry', 'tot_pop'])
# Out:
#       area_num               community  \
# 0            1             ROGERS PARK
# 1            2              WEST RIDGE
# 2            3                  UPTOWN
# 3            4          LINCOLN SQUARE
# 4            5            NORTH CENTER
# 5            6               LAKE VIEW
# 6            7            LINCOLN PARK
# 7            8         NEAR NORTH SIDE
# 8            9             EDISON PARK
# 9           10            NORWOOD PARK
# 10          11          JEFFERSON PARK
# 11          12             FOREST GLEN
# 12          13              NORTH PARK
# 13          14             ALBANY PARK
# 14          15            PORTAGE PARK
# 15          16             IRVING PARK
# 16          17                 DUNNING
# 17          18               MONTCLARE
# 18          19          BELMONT CRAGIN
# 19          20                 HERMOSA
# 20          21                AVONDALE
# 21          22            LOGAN SQUARE
# 22          23           HUMBOLDT PARK
# ...

# %%
build_year_val = build_year_val.set_index(keys="area_num")

# %%
build_year_val.stack()
# Out:
# /Users/oleksandrafilippova/miniconda3/lib/python3.9/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /Users/oleksandrafilippova/miniconda3/lib/python3.9/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# ...
