# %%
import api_collection

api_collection.process_crime("ijzp-q8t2")

# %%
gca.get_geo_comm_areas()
# Out:
#           community  area_num  \
# 0           DOUGLAS        35
# 1           OAKLAND        36
# 2       FULLER PARK        37
# 3   GRAND BOULEVARD        38
# 4           KENWOOD        39
# ..              ...       ...
# 72  MOUNT GREENWOOD        74
# 73      MORGAN PARK        75
# 74            OHARE        76
# 75        EDGEWATER        77
# 76      EDISON PARK         9
#
#                                              geometry
# 0   MULTIPOLYGON (((-87.60914 41.84469, -87.60915 ...
# 1   MULTIPOLYGON (((-87.59215 41.81693, -87.59231 ...
# 2   MULTIPOLYGON (((-87.62880 41.80189, -87.62879 ...
# 3   MULTIPOLYGON (((-87.60671 41.81681, -87.60670 ...
# 4   MULTIPOLYGON (((-87.59215 41.81693, -87.59215 ...
# ..                                                ...
# 72  MULTIPOLYGON (((-87.69646 41.70714, -87.69644 ...
# 73  MULTIPOLYGON (((-87.64215 41.68508, -87.64249 ...
# 74  MULTIPOLYGON (((-87.83658 41.98640, -87.83658 ...
# ...

# %%
build_dataframes.gca
# Out:
# <module 'geo_comm_areas' from '/Users/oleksandrafilippova/capp30122/proj-yams/geo_comm_areas.py'>

# %%
api_collection.pull_data("spqx-js37", lim = 1000)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#                              intersection camera_id                  address  \
# 0                       111TH AND HALSTED      2422       11100 S HALSTED ST
# 1                       111TH AND HALSTED      2424           800 W 111TH ST
# 2                       119TH AND HALSTED      2404       800 W 119TH STREET
# 3                       119TH AND HALSTED      2402          11900 S HALSTED
# 4    31ST ST AND MARTIN LUTHER KING DRIVE      2121  3100 S DR MARTIN L KING
# ..                                    ...       ...                      ...
# 995                     WESTERN AND TOUHY      1251    7200 N WESTERN AVENUE
# 996                     111TH AND HALSTED      2422       11100 S HALSTED ST
# 997                     111TH AND HALSTED      2424           800 W 111TH ST
# 998                     119TH AND HALSTED      2402          11900 S HALSTED
# ...
